# %% [markdown]
# # daal4py
# training a classifier using daal4py

# %%
import mlrun

mlrun.mlconf.dbpath = 'http://mlrun-api:8080'

# %% [markdown]
# ## parameters

# %%
FUNCTION           = 'clf_gbt_daal4py'               # python function file name
DESCRIPTION        = 'train a gradient boosted trees classifier using daal4py'       

IMAGE              = 'yjbds/mlrun-dask:dev'          # custom image
JOB_KIND           = 'job'                                           

TASK_NAME          = 'user-task-train-gbt-daal4py'     # whatever

ARTIFACTS_PATH     = '/User/repos/demos/dask/artifacts'

DASK_CLIENT        = 'scheduler.json'
TRAIN_SET          = ('xtrain', 'ytrain') # published names in the cluster 
VALID_SET          = ('xvalid', 'yvalid')
CATEGORIES         = ['UniqueCarrier', 'Origin', 'Dest']

MODEL_NAME         = 'logreg-daal-model.pkl'
MODEL_KEY          = 'logreg-daal-model'

# %% [markdown]
# ## load and configure function

# %%
FUNC_PY = '/User/repos/demos/dask/code/clf_gbt_daal4py.py'
FUNC_YAML = '/User/repos/demos/dask/yaml/clf_gbt_daal4py.yaml'

# %%
clf_logreg_daal = mlrun.new_function(command=FUNC_PY, image=IMAGE, kind=JOB_KIND)
clf_logreg_daal.spec.build.image = IMAGE

clf_logreg_daal.export(FUNC_YAML)
# clf_lgbm = mlrun.import_function(FUNC_YAML)

clf_logreg_daal.apply(mlrun.mount_v3io())

clf_logreg_daal.deploy(skip_deployed=True, with_mlrun=False)

# create and run the task
train_clf_logreg_daal_task = mlrun.NewTask(
    TASK_NAME, 
    handler=FUNCTION,  
    params={
        'target_path': ARTIFACTS_PATH,
        'name'       : MODEL_NAME,
        'key'        : MODEL_KEY,
        'n_classes'  : 2,
        'categories' : ['UniqueCarrier', 'Origin', 'Dest']
    })

# run
rn = clf_logreg_daal.run(train_clf_logreg_daal_task)
# Out:
# [mlrun] 2020-02-11 23:33:28,897 function spec saved to path: /User/repos/demos/dask/yaml/clf_gbt_daal4py.yaml
# [mlrun] 2020-02-11 23:33:28,905 starting run user-task-train-gbt-daal4py uid=2225d9cd6fe14a478c9731d2a6173c6e  -> http://mlrun-api:8080
# [mlrun] 2020-02-11 23:33:28,970 Job is running in the background, pod: user-task-train-gbt-daal4py-mzppf
# Found wrong dimensionality (0) of array in list when constructing SOA table (must be 1d)final state: failed
# <style>
# .dictlist {
#   background-color: #b3edff;
#   text-align: center;
#   margin: 4px;
#   border-radius: 3px; padding: 0px 3px 1px 3px; display: inline-block;}
# .artifact {
#   cursor: pointer;
#   background-color: #ffe6cc;
#   text-align: left;
#   margin: 4px; border-radius: 3px; padding: 0px 3px 1px 3px; display: inline-block;
# }
# div.block.hidden {
#   display: none;
# }
# .clickable {
#   cursor: pointer;
# }
# .ellipsis {
#   display: inline-block;
#   max-width: 60px;
#   white-space: nowrap;
#   overflow: hidden;
#   text-overflow: ellipsis;
# }
# .master-wrapper {
#   display: flex;
#   flex-flow: row nowrap;
#   justify-content: flex-start;
#   align-items: stretch;
# }
# .master-tbl {
#   flex: 3
# }
# .master-wrapper > div {
#   margin: 4px;
#   padding: 10px;
# }
# iframe.fileview {
#   border: 0 none;
#   height: 100%;
#   width: 100%;
#   white-space: pre-wrap;
# }
# .pane-header-title {
#   width: 80%;
#   font-weight: 500;
# }
# .pane-header {
#   line-height: 1;
#   background-color: #ffe6cc;
#   padding: 3px;
# }
# .pane-header .close {
#   font-size: 20px;
#   font-weight: 700;
#   float: right;
#   margin-top: -5px;
# }
# .master-wrapper .right-pane {
#   border: 1px inset silver;
#   width: 40%;
#   min-height: 300px;
#   flex: 3
#   min-width: 500px;
# }
# .master-wrapper * {
#   box-sizing: border-box;
# }
# </style><script>
# function copyToClipboard(fld) {
#     if (document.queryCommandSupported && document.queryCommandSupported('copy')) {
#         var textarea = document.createElement('textarea');
#         textarea.textContent = fld.innerHTML;
#         textarea.style.position = 'fixed';
#         document.body.appendChild(textarea);
#         textarea.select();
#
#         try {
#             return document.execCommand('copy'); // Security exception may be thrown by some browsers.
#         } catch (ex) {
#
#         } finally {
#             document.body.removeChild(textarea);
#         }
#     }
# }
# function expandPanel(el) {
#   const panelName = "#" + el.getAttribute('paneName');
#   console.log(el.title);
#
#   document.querySelector(panelName + "-title").innerHTML = el.title
#   iframe = document.querySelector(panelName + "-body");
#
#   const tblcss = `<style> body { font-family: Arial, Helvetica, sans-serif;}
#     #csv { margin-bottom: 15px; }
#     #csv table { border-collapse: collapse;}
#     #csv table td { padding: 4px 8px; border: 1px solid silver;} </style>`;
#
#   function csvToHtmlTable(str) {
#     return '<div id="csv"><table><tr><td>' +  str.replace(/[\n\r]+$/g, '').replace(/[\n\r]+/g, '</td></tr><tr><td>')
#       .replace(/,/g, '</td><td>') + '</td></tr></table></div>';
#   }
#
#   function reqListener () {
#     if (el.title.endsWith(".csv")) {
#       iframe.setAttribute("srcdoc", tblcss + csvToHtmlTable(this.responseText));
#     } else {
#       iframe.setAttribute("srcdoc", this.responseText);
#     }
#     console.log(this.responseText);
#   }
#
#   const oReq = new XMLHttpRequest();
#   oReq.addEventListener("load", reqListener);
#   oReq.open("GET", el.title);
#   oReq.send();
#
#
#   //iframe.src = el.title;
#   const resultPane = document.querySelector(panelName + "-pane");
#   if (resultPane.classList.contains("hidden")) {
#     resultPane.classList.remove("hidden");
#   }
# }
# function closePanel(el) {
#   const panelName = "#" + el.getAttribute('paneName')
#   const resultPane = document.querySelector(panelName + "-pane");
#   if (!resultPane.classList.contains("hidden")) {
#     resultPane.classList.add("hidden");
#   }
# }
#
# </script>
# <div class="master-wrapper">
#   <div class="block master-tbl"><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>uid</th>
#       <th>iter</th>
#       <th>start</th>
#       <th>state</th>
#       <th>name</th>
#       <th>labels</th>
#       <th>inputs</th>
#       <th>parameters</th>
#       <th>results</th>
#       <th>artifacts</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td><div title="2225d9cd6fe14a478c9731d2a6173c6e">...173c6e</div></td>
#       <td>0</td>
#       <td>Feb 11 23:33:38</td>
#       <td><div style="color: red;" title="error, check logs">error</div></td>
#       <td>clf_gbt_daal4py</td>
#       <td><div class="dictlist">host=user-task-train-gbt-daal4py-mzppf</div><div class="dictlist">kind=job</div><div class="dictlist">owner=admin</div></td>
#       <td></td>
#       <td><div class="dictlist">categories=['UniqueCarrier', 'Origin', 'Dest']</div><div class="dictlist">key=logreg-daal-model</div><div class="dictlist">n_classes=2</div><div class="dictlist">name=logreg-daal-model.pkl</div><div class="dictlist">target_path=/User/repos/demos/dask/artifacts</div></td>
#       <td></td>
#       <td></td>
#     </tr>
#   </tbody>
# </table>
# </div></div>
#   <div id="resultd21ac522-pane" class="right-pane block hidden">
#     <div class="pane-header">
#       <span id="resultd21ac522-title" class="pane-header-title">Title</span>
#       <span onclick="closePanel(this)" paneName="resultd21ac522" class="close clickable">&times;</span>
#     </div>
#     <iframe class="fileview" id="resultd21ac522-body"></iframe>
#   </div>
# </div>
# to track results use .show() or .logs() or in CLI:
# !mlrun get run 2225d9cd6fe14a478c9731d2a6173c6e  , !mlrun logs 2225d9cd6fe14a478c9731d2a6173c6e
# [mlrun] 2020-02-11 23:38:19,099 run executed, status=error
# runtime error: error, check logs
# ---------------------------------------------------------------------------
# RunError                                  Traceback (most recent call last)
# <ipython-input-12-5eaee630df9b> in <module>
#      22
#      23 # run
# ---> 24 rn = clf_logreg_daal.run(train_clf_logreg_daal_task)
#
# ~/.pythonlibs/jupyter-1/lib/python3.6/site-packages/mlrun/runtimes/base.py in run(self, runspec, handler, name, project, params, inputs, out_path, workdir, watch, schedule)
#     268                 result = self._post_run(task=runspec, err=err)
#     269                 return self._wrap_result(result, runspec, err=err)
# --> 270             return self._wrap_result(resp, runspec)
#     271
#     272         elif self._is_remote and not self._is_api_server and not self.kfp:
#
# ~/.pythonlibs/jupyter-1/lib/python3.6/site-packages/mlrun/runtimes/base.py in _wrap_result(self, result, runspec, err)
#     336                 if self._is_remote and not self.is_child:
#     337                     print('runtime error: {}'.format(run.status.error))
# --> 338                 raise RunError(run.status.error)
#     339             return run
#     340
#
# RunError: error, check logs
