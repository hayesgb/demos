# %% [markdown]
# # Deploy a Serverless Model Server with Nuclio-KFServing
#   --------------------------------------------------------------------
#
# The following notebook demonstrates how to deploy **any pickled model** using **[nuclio](https://github.com/nuclio/nuclio)** + **[KFServing](https://github.com/kubeflow/kfserving)** (a.k.a <b>Nuclio-serving</b>)
#
# #### **notebook how-to's**
# * Write and test model serving (KFServing) class in a notebook.
# * Deploy the model server as a Nuclio-serving function.
# * Invoke and test the serving function.

# %% [markdown]
# <a id='top'></a>
# #### **steps**
# **[define a new function and its dependencies](#define-function)**<br>
# **[test the model serving class locally](#test-locally)**<br>
# **[deploy our serving class using as a serverless function](#deploy)**<br>
# **[test our model server using HTTP request](#test-model-server)**<br>

# %%
# nuclio: ignore
# if the nuclio-jupyter package is not installed run !pip install nuclio-jupyter
import nuclio

# %% [markdown]
# <a id='define-function'></a>
# ### **define a new function and its dependencies**

# %%
# %nuclio config kind="nuclio:serving"
# %nuclio env MODEL_CLASS=ClassifierModel
# Out:
# %nuclio: setting kind to 'nuclio:serving'
# %nuclio: setting 'MODEL_CLASS' environment variable

# %%
# %%nuclio cmd -c
# pip install -U -q kfserving
# pip install -U -q azure
# pip install -U -q mlrun

# %%
# %nuclio config spec.build.baseImage = "yjbds/mlrun-files:latest"

# %%
import kfserving
import os
import numpy as np
from cloudpickle import load

# %%
TARGET_PATH = '/User/repos/demos/dask/artifacts'
MODEL_FILE = 'lgbm-model.pkl'

# %%
class ClassifierModel(kfserving.KFModel):
    def __init__(self, name: str, model_dir: str, model = None):
        super().__init__(name)
        self.name = name
        self.model_dir = model_dir
        if not model is None:
            self.classifier = model
            self.ready = True

    def load(self):
        model_file = os.path.join(
            kfserving.Storage.download(self.model_dir), MODEL_FILE)
        self.classifier = load(open(model_file, 'rb'))
        self.ready = True

    def predict(self, body):
        try:
            feats = np.asarray(body['instances'])
            result: np.ndarray = self.classifier.predict(feats)
            return result.tolist()
        except Exception as e:
            raise Exception("Failed to predict %s" % e)

# %% [markdown]
# The following end-code annotation tells ```nuclio``` to stop parsing the notebook from this cell. _**Please do not remove this cell**_:

# %%
# nuclio: end-code

# %% [markdown]
# ______________________________________________

# %% [markdown]
# <a id='test-locally'></a>
# ### **test the model serving class locally**
# The class above can be tested locally. Just instantiate the class, `.load()` will load the model to a local dir.
#
# > **Verify there is a `model.bst` file in the model_dir path (generated by the training notebook)**

# %%
model = load(open(TARGET_PATH + '/' + MODEL_FILE, 'rb'))
# Out:
# /User/.pythonlibs/jupyter-1/lib/python3.6/site-packages/sklearn/base.py:318: UserWarning: Trying to unpickle estimator LabelEncoder from version 0.21.3 when using version 0.22.1. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)

# %%
model
# Out:
# LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#                importance_type='split', learning_rate=0.1,
#                local_listen_port=12400,
#                machines='10.233.64.55:12400,10.233.64.58:12401,10.233.64.56:12402,10.233.64.52:12403,10.233.64.53:12404,10.233.64.54:12405,10.233.64.59:12406,10.233.64.57:12407',
#                max_depth=3, min_child_samples=20, min_child_weight=0.001,
#                min_split_gain=0.0, n_estimators=3, n_jobs=-1, num_leaves=31,
#                num_machines=8, num_threads=1, objective=None, random_state=1,
#                reg_alpha=0.0, reg_lambda=0.0, silent=False, subsample=1.0,
#                subsample_for_bin=200000, subsample_freq=0, time_out=120,
#                tree_learner='data')

# %%
my_server = ClassifierModel('classifier', model_dir=TARGET_PATH, model = model)
my_server.load()
# Out:
# [I 200211 15:20:58 storage:35] Copying contents of /User/repos/demos/dask/artifacts to local

# %% [markdown]
# ### _data_
# Make some classification data using scikit learn's `make_classification`:

# %%
import dask
import pandas as pd
import dask.dataframe as dd
import pyarrow.parquet as pq
import pyarrow

# %%
xtest = pd.read_parquet('/User/repos/demos/dask/artifacts/test_set')

# %%
xtest.head()
# Out:
#    index  Year  Month  DayofMonth  DayOfWeek  CRSDepTime  UniqueCarrier  \
# 0   4406  1998     11          11          3      1745.0              0
# 1   6183  1998     11          26          4       600.0              0
# 2   8481  1998     11           3          2      1300.0              0
# 3   1701  1998     11          15          7       700.0              7
# 4     25  1998     11           3          2       840.0              2
#
#    Origin  Dest  Distance  ArrDelay
# 0       5     0     859.0     False
# 1       6     0     259.0     False
# 2       9     0     547.0     False
# 3      27     3     723.0     False
# 4      15     2     328.0     False

# %%
xtest.pop('index')
# Out:
# 0         4406
# 1         6183
# 2         8481
# 3         1701
# 4           25
# 5         3890
# 6         7234
# 7         5957
# 8         2021
# 9         8363
# 10         967
# 11        5455
# 12        1921
# 13        5924
# 14        3595
# 15        4185
# 16        7207
# 17        4415
# 18        4541
# 19        1468
# 20         455
# 21        1851
# 22        4401
# 23        1710
# 24         285
# 25        1501
# 26        5346
# 27        3365
# 28        9251
# 29        9770
#           ...
# 278534    4479
# 278535    3094
# 278536       4
# 278537    6085
# 278538    9582
# 278539    8433
# 278540    7013
# 278541     637
# 278542    9544
# 278543    8939
# 278544    5313
# 278545    3224
# 278546    6395
# 278547    4735
# 278548    8488
# 278549    5279
# 278550    3164
# 278551    5446
# 278552    2400
# 278553    2603
# 278554    7844
# 278555    1460
# 278556    7029
# 278557    2834
# 278558      14
# 278559    2753
# 278560     864
# 278561    4693
# 278562    3620
# 278563    7925
# Name: index, Length: 278564, dtype: int64

# %%
ytest = xtest.pop('ArrDelay')

# %%
event = {"instances": xtest.values.tolist()}

# %%
ytest
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
# 5         False
# 6         False
# 7         False
# 8         False
# 9         False
# 10        False
# 11        False
# 12        False
# 13         True
# 14        False
# 15         True
# 16        False
# 17        False
# 18         True
# 19         True
# 20        False
# 21        False
# 22        False
# 23        False
# 24        False
# 25        False
# 26        False
# 27        False
# 28        False
# 29        False
#           ...
# 278534     True
# 278535    False
# 278536    False
# 278537    False
# 278538     True
# 278539    False
# 278540    False
# 278541    False
# 278542    False
# 278543    False
# 278544     True
# 278545     True
# 278546     True
# 278547    False
# 278548    False
# 278549     True
# 278550    False
# 278551    False
# 278552    False
# 278553    False
# 278554    False
# 278555     True
# 278556    False
# 278557    False
# 278558    False
# 278559    False
# 278560    False
# 278561    False
# 278562    False
# 278563    False
# Name: ArrDelay, Length: 278564, dtype: bool

# %%
my_server.predict(event)
# Out:
# [False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  ...]

# %% [markdown]
# <a id='deploy'></a>
# ### **deploy our serving class using as a serverless function**

# %%
import mlrun
import requests

# %%
fn = mlrun.new_model_server('generic', 
                            models={'classifier_gen': TARGET_PATH}, 
                            model_class='ClassifierModel').apply(mlrun.mount_v3io())

# %%
fn.spec.no_cache = True

# %%
addr = fn.deploy()
# Out:
# [mlrun] 2020-02-11 15:22:03,835 deploy started
# [nuclio] 2020-02-11 15:26:04,298 (error) Failed to deploy. Details:
#
# Error - Kaniko job failed. Job logs:
# INFO[0000] Resolved base name docker-registry.default-tenant.app.yjb-ds-3.iguazio-cd2.com:80/nuclio/handler-builder-python-onbuild:1.3.13-amd64 to docker-registry.default-tenant.app.yjb-ds-3.iguazio-cd2.com:80/nuclio/handler-builder-python-onbuild:1.3.13-amd64
# INFO[0000] Resolved base name python:3.6 to python:3.6
# INFO[0000] Resolved base name docker-registry.default-tenant.app.yjb-ds-3.iguazio-cd2.com:80/nuclio/handler-builder-python-onbuild:1.3.13-amd64 to docker-registry.default-tenant.app.yjb-ds-3.iguazio-cd2.com:80/nuclio/handler-builder-python-onbuild:1.3.13-amd64
# INFO[0000] Resolved base name python:3.6 to python:3.6
# INFO[0000] Downloading base image docker-registry.default-tenant.app.yjb-ds-3.iguazio-cd2.com:80/nuclio/handler-builder-python-onbuild:1.3.13-amd64
# INFO[0000] Error while retrieving image from cache: getting file info: stat /cache/sha256:82cd293d3756dd16d6510d5fccb7613c6cd0895ea5b29fc891f7ee9b28013c45: no such file or directory
# INFO[0000] Downloading base image docker-registry.default-tenant.app.yjb-ds-3.iguazio-cd2.com:80/nuclio/handler-builder-python-onbuild:1.3.13-amd64
# INFO[0000] Downloading base image python:3.6
# INFO[0000] Error while retrieving image from cache: getting file info: stat /cache/sha256:764b2c6beae96a8c8c6046392d5b1b691773337c5a7fd29347935ee0a3223146: no such file or directory
# INFO[0000] Downloading base image python:3.6
# INFO[0000] Built cross stage deps: map[0:[/home/nuclio/bin/processor /home/nuclio/bin/py]]
# INFO[0000] Downloading base image docker-registry.default-tenant.app.yjb-ds-3.iguazio-cd2.com:80/nuclio/handler-builder-python-onbuild:1.3.13-amd64
# INFO[0000] Error while retrieving image from cache: getting file info: stat /cache/sha256:82cd293d3756dd16d6510d5fccb7613c6cd0895ea5b29fc891f7ee9b28013c45: no such file or directory
# INFO[0000] Downloading base image docker-registry.default-tenant.app.yjb-ds-3.iguazio-cd2.com:80/nuclio/handler-builder-python-onbuild:1.3.13-amd64
# INFO[0001] Taking snapshot of full filesystem...
# INFO[0001] ARG NUCLIO_LABEL
# INFO[0001] ARG NUCLIO_ARCH
# INFO[0001] Saving file /home/nuclio/bin/processor for later use.
# INFO[0001] Saving file /home/nuclio/bin/py for later use.
# INFO[0001] Deleting filesystem...
# INFO[0001] Downloading base image python:3.6
# INFO[0001] Error while retrieving image from cache: getting file info: stat /cache/sha256:764b2c6beae96a8c8c6046392d5b1b691773337c5a7fd29347935ee0a3223146: no such file or directory
# INFO[0001] Downloading base image python:3.6
# INFO[0001] Unpacking rootfs as cmd RUN pip install -U -q kfserving requires it.
# INFO[0014] Taking snapshot of full filesystem...
# INFO[0022] ARG NUCLIO_LABEL
# INFO[0022] ARG NUCLIO_ARCH
# INFO[0022] ARG NUCLIO_BUILD_LOCAL_HANDLER_DIR
# INFO[0022] RUN pip install -U -q kfserving
# INFO[0022] cmd: /bin/sh
# INFO[0022] args: [-c pip install -U -q kfserving]
# INFO[0044] Taking snapshot of full filesystem...
# INFO[0050] RUN pip install -U -q azure
# INFO[0050] cmd: /bin/sh
# INFO[0050] args: [-c pip install -U -q azure]
# INFO[0086] Taking snapshot of full filesystem...
# INFO[0098] Adding whiteout for /usr/local/lib/python3.6/site-packages/azure_storage_common-2.1.0.dist-info
# INFO[0098] Adding whiteout for /usr/local/lib/python3.6/site-packages/azure_storage_blob-2.1.0.dist-info
# INFO[0107] RUN pip install -U -q mlrun
# INFO[0107] cmd: /bin/sh
# INFO[0107] args: [-c pip install -U -q mlrun]
# ERROR: kfserving 0.2.2.1 has requirement kubernetes>=10.0.1, but you'll have kubernetes 10.0.0 which is incompatible.
# INFO[0144] Taking snapshot of full filesystem...
# INFO[0147] Adding whiteout for /usr/local/lib/python3.6/site-packages/kubernetes-10.0.1.dist-info
# INFO[0147] Adding whiteout for /usr/local/lib/python3.6/site-packages/urllib3-1.25.8.dist-info
# INFO[0158] COPY --from=python-onbuild /home/nuclio/bin/processor /usr/local/bin/processor
# INFO[0158] Taking snapshot of files...
# INFO[0159] COPY --from=python-onbuild /home/nuclio/bin/py /opt/nuclio/
# INFO[0159] Taking snapshot of files...
# INFO[0159] Using files from context: [/tmp/nuclio-build-382270166/staging/handler]
# INFO[0159] COPY handler /opt/nuclio
# INFO[0159] Taking snapshot of files...
# INFO[0159] RUN pip install nuclio-sdk msgpack --no-index --find-links /opt/nuclio/whl
# INFO[0159] cmd: /bin/sh
# INFO[0159] args: [-c pip install nuclio-sdk msgpack --no-index --find-links /opt/nuclio/whl]
# Looking in links: /opt/nuclio/whl
# Requirement already satisfied: nuclio-sdk in /usr/local/lib/python3.6/site-packages (0.0.7)
# Processing /opt/nuclio/whl/msgpack-0.6.1.tar.gz
# Building wheels for collected packages: msgpack
#   Building wheel for msgpack (setup.py): started
#   Building wheel for msgpack (setup.py): finished with status 'done'
#   Created wheel for msgpack: filename=msgpack-0.6.1-cp36-cp36m-linux_x86_64.whl size=273469 sha256=f9b34db46bcc9d237553b1c105ce098d75252857b92635c221b5792f3cf22e81
#   Stored in directory: /root/.cache/pip/wheels/19/df/c3/08424fe5285667aff8a58a69c995c723ffa81c4208138d6d0f
# Successfully built msgpack
# Installing collected packages: msgpack
# Successfully installed msgpack-0.6.1
# INFO[0164] Taking snapshot of full filesystem...
# INFO[0169] CMD [ "processor" ]
# error pushing image: failed to push to destination docker-registry.default-tenant.app.yjb-ds-3.iguazio-cd2.com:80/nuclio/default-generic-processor:latest: Patch http://docker-registry.default-tenant.app.yjb-ds-3.iguazio-cd2.com:80/v2/nuclio/default-generic-processor/blobs/uploads/e956dde3-5828-4790-897a-f15f7daf7963?_state=evmTtkzuPttzb8UsO_jQsAJk1pxkOuK0iyG-5s34o0V7Ik5hbWUiOiJudWNsaW8vZGVmYXVsdC1nZW5lcmljLXByb2Nlc3NvciIsIlVVSUQiOiJlOTU2ZGRlMy01ODI4LTQ3OTAtODk3YS1mMTVmN2RhZjc5NjMiLCJPZmZzZXQiOjAsIlN0YXJ0ZWRBdCI6IjIwMjAtMDItMTFUMTU6MjQ6NTguMTAxMzUwNjczWiJ9: EOF
#     .../nuclio/nuclio/pkg/processor/build/builder.go:242
# ---------------------------------------------------------------------------
# DeployError                               Traceback (most recent call last)
# <ipython-input-63-a6ae5dec0e5d> in <module>
# ----> 1 addr = fn.deploy()
#
# ~/.pythonlibs/jupyter-1/lib/python3.6/site-packages/mlrun/runtimes/function.py in deploy(self, dashboard, project, tag, kind)
#     234                 config, dashboard, name=self.metadata.name,
#     235                 project=project, tag=tag, verbose=self.verbose,
# --> 236                 create_new=True)
#     237         else:
#     238
#
# ~/.pythonlibs/jupyter-1/lib/python3.6/site-packages/nuclio/deploy.py in deploy_config(config, dashboard_url, name, project, tag, verbose, create_new)
#     257     if state != 'ready':
#     258         log('ERROR: {}'.format(resp.text))
# --> 259         raise DeployError('cannot deploy ' + resp.text)
#     260
#     261     logger.info('done %s %s, function address: %s', verb, name, address)
#
# DeployError: cannot deploy

# %% [markdown]
# <a id="test-model-server"></a>
# ### **test our model server using HTTP request**

# %%
import json
import requests

resp = requests.post(addr + '/classifier_gen/predict', json=event)

# %%
resp.__dict__['_content']

# %%
json.loads(resp.content)

# %% [markdown]
# **[back to top](#top)**
